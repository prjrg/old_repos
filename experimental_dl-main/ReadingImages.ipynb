# %%
# !wget https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg
# Out:
# --2020-12-09 11:09:20--  https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6023:1::a27d:4301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/l98leemr7r5stnm/Hemanvi.jpeg [following]
# --2020-12-09 11:09:21--  https://www.dropbox.com/s/raw/l98leemr7r5stnm/Hemanvi.jpeg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com/cd/0/inline/BEsH__kHIvS3h3Uk8LXQIw0EPr2qag3Sgz4sg9ivzS--o3dn16jRNewmlFA1VYpMQ3nqdMPigdh6I2CMjoVeA9vfi2HhhmO0unIUkeLakFQL4g/file# [following]
# --2020-12-09 11:09:21--  https://uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com/cd/0/inline/BEsH__kHIvS3h3Uk8LXQIw0EPr2qag3Sgz4sg9ivzS--o3dn16jRNewmlFA1VYpMQ3nqdMPigdh6I2CMjoVeA9vfi2HhhmO0unIUkeLakFQL4g/file
# Resolving uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com (uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com)... 162.125.68.15, 2620:100:6023:15::a27d:430f
# Connecting to uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com (uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com)|162.125.68.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53839 (53K) [image/jpeg]
# Saving to: ‘Hemanvi.jpeg’
#
# Hemanvi.jpeg        100%[===================>]  52,58K  --.-KB/s    in 0,04s
#
# 2020-12-09 11:09:22 (1,36 MB/s) - ‘Hemanvi.jpeg’ saved [53839/53839]

# %%
# %matplotlib inline
import cv2, matplotlib.pyplot as plt

# %%
img = cv2.imread('Hemanvi.jpeg')

# %%
img = img[50:250, 40:240]
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')

# %%
img_gray_small = cv2.resize(img_gray, (25, 25))
plt.imshow(img_gray_small, cmap='gray')

# %%
# !wget https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg
# Out:
# --2020-12-09 11:16:57--  https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6023:1::a27d:4301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/l98leemr7r5stnm/Hemanvi.jpeg [following]
# --2020-12-09 11:16:57--  https://www.dropbox.com/s/raw/l98leemr7r5stnm/Hemanvi.jpeg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com/cd/0/inline/BEsH__kHIvS3h3Uk8LXQIw0EPr2qag3Sgz4sg9ivzS--o3dn16jRNewmlFA1VYpMQ3nqdMPigdh6I2CMjoVeA9vfi2HhhmO0unIUkeLakFQL4g/file# [following]
# --2020-12-09 11:16:57--  https://uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com/cd/0/inline/BEsH__kHIvS3h3Uk8LXQIw0EPr2qag3Sgz4sg9ivzS--o3dn16jRNewmlFA1VYpMQ3nqdMPigdh6I2CMjoVeA9vfi2HhhmO0unIUkeLakFQL4g/file
# Resolving uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com (uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com)... 162.125.68.15, 2620:100:6023:15::a27d:430f
# Connecting to uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com (uc42f00716b1a34551bff011012e.dl.dropboxusercontent.com)|162.125.68.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53839 (53K) [image/jpeg]
# Saving to: ‘Hemanvi.jpeg.1’
#
# Hemanvi.jpeg.1      100%[===================>]  52,58K  --.-KB/s    in 0,03s
#
# 2020-12-09 11:16:58 (1,80 MB/s) - ‘Hemanvi.jpeg.1’ saved [53839/53839]

# %%
img = cv2.imread('Hemanvi.jpeg')

# %%
img = img[50:250, 40:240, :]

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
crop = img[-3:, -3:]

# %%
plt.imshow(crop)
